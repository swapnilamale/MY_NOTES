# %% [markdown]
# ![{C41DF319-4B06-4BC1-9A81-189C0001D325}.png](attachment:a053c94e-a5a5-49c7-97d5-0a69e1f33003.png)

# %% [markdown]
# ### Python

# %% [markdown]
# ```
# Python
# OOP's
# DSA
# Module Creation
# creating python environment
#
# numpy/pandas/matplotlib/seaborn
# creating pipeline
# Sklearn , TensorFlow
# pyspark
# pdb | joblib | tqdm | os | sys | datetime | regular expression
# ```

# %% [markdown]
# ### Other Tech Skill

# %% [markdown]
# ```
# SQL
# Mongo
#
# Excel
# Tableau
# PowerBI
#
#
# word
# powerpoint
# latex
#
# Git
# Linux
# Docker
# Streamlit
# Fask
#
# nltk/spacy
#
# VS Code
# ```

# %% [markdown]
# ```
# Video Editing
#
# ```

# %% [markdown]
# ## ML

# %% [markdown]
# ```
# Linear Aljebra
# --------------
#
# Statastics & Probability
# ------------------------
#
# EDA
# -----
# Feature Engineering
#
#
# Supervised Learning
# -------------------
# Distance : KNN
# Probalistic : NB
# Geometric : Linear Regression | Logistic Regression | SVM
# Infomation Theory : DT | RF | Adaboost | GBDT (XGBOOST)
#
#
# Usupervised Learning
# ---------------------
# PCA
# Tsne
# Clusturing (K-means, Herachical)
#
#
# Recommender System
# -------------------
#
# Time Series Analysis
# --------------------
#
#
# Deep Learning
# ---------------
# ANN, RNN , CNN
#
#
# Deep Learning
# ---------------
#
# GenAI
# ------
#
# MLOps
# ------
# Docker
# Flask
# Cloud
#
#
# System Design
# ------------
#
# Product Analytics
# -----------------
#
#
# Networking
# -----------
#
# ```
